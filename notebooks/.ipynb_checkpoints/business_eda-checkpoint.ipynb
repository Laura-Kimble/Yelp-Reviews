# %%
businesses_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b5f43ef7174c> in <module>
# ----> 1 businesses_df
#
# NameError: name 'businesses_df' is not defined

# %%
pwd
# Out:
# '/home/jovyan/work/DSI/yelp/Yelp-Reviews/notebooks'

# %%
cd ..
# Out:
# /home/jovyan/work/DSI/yelp/Yelp-Reviews

# %%
cd src/
# Out:
# /home/jovyan/work/DSI/yelp/Yelp-Reviews/src

# %%
run clean_data.py

# %%
businesses_df
# Out:
#                               address AcceptsInsurance AgesAllowed  \
# 0                30 Eglinton Avenue W             None        None
# 1           10110 Johnston Rd, Ste 15             None        None
# 2                 6007 Dean Martin Dr             None        None
# 3               6055 E Lake Mead Blvd             None        None
# 4      17025 N Scottsdale Rd, Ste 110             None        None
# ...                               ...              ...         ...
# 13119         5611 S Valley View Blvd             None        None
# 13120        9719 Sam Furr Rd, Unit C             None        None
# 13121                578 Yonge Street             None        None
# 13122   8164 S. Las Vegas Blvd., #100             None        None
# 13123              5350 E Marriott Dr             None        None
#
#                 Alcohol                                           Ambience  \
# 0           u'full_bar'  {'romantic': False, 'intimate': False, 'classy...
# 1      u'beer_and_wine'  {'romantic': False, 'intimate': False, 'touris...
# 2           u'full_bar'  {'romantic': False, 'intimate': True, 'classy'...
# 3      u'beer_and_wine'  {'romantic': False, 'intimate': False, 'classy...
# 4                  None                                               None
# ...                 ...                                                ...
# 13119           u'none'  {'touristy': False, 'hipster': False, 'romanti...
# 13120  u'beer_and_wine'  {'touristy': False, 'hipster': False, 'romanti...
# 13121  u'beer_and_wine'  {'touristy': False, 'hipster': False, 'romanti...
# 13122              None                                               None
# 13123              None                                               None
#
#        BYOB BYOBCorkage BestNights BikeParking BusinessAcceptsBitcoin  ...  \
# 0      None        None       None       False                   None  ...
# 1      None        None       None        True                   None  ...
# 2      None        None       None       False                   None  ...
# 3      None        None       None        True                   None  ...
# 4      None        None       None        True                   None  ...
# ...     ...         ...        ...         ...                    ...  ...
# 13119  None        None       None        True                  False  ...
# 13120  None        None       None        True                   None  ...
# 13121  None        None       None        True                   None  ...
# 13122  None        None       None        True                   None  ...
# 13123  None        None       None        None                  False  ...
#
#            Tuesday    Wednesday is_open   latitude   longitude  \
# 0          9:0-0:0      9:0-0:0       1  43.605499  -79.652289
# 1             None  17:30-21:30       1  35.092564  -80.859132
# 2             None         None       1  36.080168 -115.182756
# 3        10:0-21:0    10:0-21:0       1  36.195615 -115.040529
# 4         9:0-18:0     9:0-18:0       1  33.640308 -111.924528
# ...            ...          ...     ...        ...         ...
# 13119  11:30-20:30  11:30-20:30       1  36.087895 -115.190329
# 13120    11:0-21:0    11:0-21:0       1  35.443723  -80.864550
# 13121    11:0-23:0    11:0-23:0       1  43.665120  -79.384809
# 13122      0:0-0:0      0:0-0:0       1  36.041407 -115.171698
# 13123      0:0-0:0      0:0-0:0       1  33.683910 -111.966235
#
#                                                 name postal_code review_count  \
# 0                         Emerald Chinese Restaurant     L5R 3E7          128
# 1                        Musashi Japanese Restaurant       28210          170
# 2                                       Hunk Mansion       89118          107
# 3                Maria's Mexican Restaurant & Bakery       89156          184
# 4                                Nothing Bundt Cakes       85255          174
# ...                                              ...         ...          ...
# 13119                               Jessie Rae's BBQ       89118          595
# 13120                      Antico Italian Restaurant       28078          142
# 13121                                   Thai Fantasy     M4Y 1Z3          113
# 13122                                      Starbucks       89123          138
# 13123  JW Marriott Phoenix Desert Ridge Resort & Spa       85054          441
#
#       stars state
# 0       2.5    ON
# 1       4.0    NC
# 2       4.0    NV
# 3       4.5    NV
# 4       4.0    AZ
# ...     ...   ...
# 13119   4.5    NV
# 13120   4.5    NC
# 13121   4.0    ON
# 13122   3.0    NV
# 13123   4.0    AZ
#
# [13124 rows x 58 columns]

# %%
type(businesses_df)
# Out:
# business_df.BusinessDF

# %%
import business_df as bd

# %%
businesses_df.plot_hist('stars', 'DogsAllowed')

# %%
type(businesses)
# Out:
# pandas.core.frame.DataFrame

# %%
import business_df as bd
businesses_df = bd.BusinessDF(businesses)

# %%
ax = businesses_df['stars'].hist(bins=9)
ax.set_title('Average Star Rating: Distribution for All Businesses')
ax.set_xlabel('avg. stars')
ax.set_ylabel('count of businesses')
# Out:
# Text(0, 0.5, 'count of businesses')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
plt.style.use('ggplot')
plt.rcParams.update({'font.size': 14})

# %%
ax = businesses_df['stars'].hist(bins=8)
ax.set_title('Average Star Rating: Distribution for All Businesses')
ax.set_xlabel('avg. stars')
ax.set_ylabel('count of businesses')

fig = ax.figure
fig.set_size_inches(8, 5)
fig.tight_layout(pad=1)
fig.savefig('../images/Overall_stars_hist.png')

# %%
cutoff = 2000
data = businesses_df[businesses_df['review_count'] < cutoff]['review_count']
ax = data.plot.hist(bins=20)
ax.set_title('Review Counts: All Businesses')
ax.set_xlabel('review count')
ax.set_ylabel('count of businesses')
ax.set_xlim(0, cutoff)

fig = ax.figure
fig.set_size_inches(8, 5)
fig.tight_layout(pad=1)
fig.savefig('../images/Overall_reviewCounts_hist.png')

# %%
ax = businesses_df['DogsAllowed'].hist()
ax.set_title('DogsAllowed')
ax.set_ylabel('count of businesses')

fig = ax.figure
fig.set_size_inches(8, 5)
fig.tight_layout(pad=1)
# fig.savefig('../images/Overall_stars_hist.png')

# %%
businesses_df['Restaurant'] = businesses_df['categories'].str.contains(pat='Restaurant')

# %%
businesses_df['Restaurant'].value_counts()
# Out:
# True     9832
# False    3292
# Name: Restaurant, dtype: int64

# %%
import business_df as bd

# %%
businesses_df.plot_hist('stars', 'DogsAllowed')

# %%
businesses_df = bd.BusinessDF(businesses)

# %%
pwd
# Out:
# '/home/jovyan/work/DSI/yelp/Yelp-Reviews/src'

# %%
run clean_data.py

# %%
type(businesses_df)
# Out:
# business_df.BusinessDF

# %%
type(businesses)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams.update({'font.size': 14})
from importlib import reload
import business_df as bd
reload(business_df)
from business_df import *

businesses_df = bd.BusinessDF(businesses)
businesses_df['Restaurant'] = businesses_df['categories'].str.contains(pat='Restaurant')
businesses_df = pd.read_pickle('../data/pickled_businesses_df')

# %%
businesses_df['Restaurant'].value_counts()
# Out:
# True     9832
# False    3292
# Name: Restaurant, dtype: int64

# %%
businesses_df.plot_value_counts_bar('categories', filter_by=('Restaurant', [False]))

# %%
businesses_df.plot_stars_hist('city', limit=5, save=True)

# %%
businesses_df.plot_review_counts_hist('city', limit=5, cutoff=1000, save=True)

# %%
restaurants = businesses_df[businesses_df['Restaurant']==True]
restaurants = bd.BusinessDF(restaurants)

# %%
businesses_df.plot_stars_hist('DogsAllowed', limit=3)

# %%
fig, ax = plt.subplots()
data = businesses_df[businesses_df['review_count']<5000]
x = data['stars']
y = data['review_count']
ax.scatter(x, y)
ax.set_xlabel('avg star rating')
ax.set_ylabel('number of reviews')
title = 'Avg. Star Rating vs. Number of Reviews'
ax.set_title(title)
fig.savefig(f'../images/{title}.png')

# %%
where = ('DogsAllowed', ['True'])
col, val = where
dogs = businesses_df[businesses_df[col].isin(val)]

# %%
dogs.shape
# Out:
# (467, 59)

# %%
businesses_df.plot_value_counts_bar('city', filter_by=('BusinessAcceptsBitcoin', ['True']))

# %%
businesses_df.to_pickle('../data/pickled_businesses_df')

# %%
businesses_test_df = pd.read_pickle('../data/pickled_businesses_df')

# %%
type(businesses_test_df)
# Out:
# business_df.BusinessDF

# %%
col_name = 'city'
col, vals = ('BusinessAcceptsBitcoin', ['True'])
filtered = businesses_df[businesses_df[col].isin(vals)]
legend_label = f'count of businesses where {col} is in {vals}'

fig, ax = plt.subplots(1, 1, figsize=(10, 6))
data = filtered[col_name].value_counts()[0:10]
labels = data.index
N = len(labels)
tick_locations = np.arange(N)

restaurant_counts = []
non_restaurant_counts = []

for lab in labels:
    restaurant_data = filtered[(filtered['Restaurant']==True) & (filtered[col_name]==lab)]
    non_restaurant_data = filtered[(filtered['Restaurant']==False) & (filtered[col_name]==lab)]
    restaurant_counts.append(len(restaurant_data))
    non_restaurant_counts.append(len(non_restaurant_data))
        
ax.barh(tick_locations, restaurant_counts, label='Restaurants')
ax.barh(tick_locations, non_restaurant_counts, label='Not Restaurants', left=restaurant_counts)
ax.set_yticks(ticks=tick_locations)
ax.set_yticklabels(labels)
ax.set_xticks(np.arange(0, max(restaurant_counts) + max(non_restaurant_counts) + 1, step=5))
ax.set_xlabel('number of businesses')
ax.set_ylabel(f'{col_name}')
title = f'Businesses that Accept Bitcoin by {col_name}'
ax.set_title(title)
ax.legend()
plt.gca().invert_yaxis()
fig.savefig(f'../images/{title}.png')

# %%
restaurant_data = filtered[(filtered['Restaurant']==True) & (filtered['city']=='Las Vegas')]

# %%
max(restaurant_counts) + max(non_restaurant_counts)
# Out:
# 20
